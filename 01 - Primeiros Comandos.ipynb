# %% [markdown]
# ##Aula de Programação para Data Sciency

# %%
print("hello word!!")
# Out:
# hello word!!

# %% [markdown]
# ##Primeiro Comando

# %%
# Mostrando um calculo numerico

print(7+4)
# Out:
# 11

# %%
# Mostrando uma concatenação de textos

print('Ola '+'Mundo')
# Out:
# Ola Mundo

# %%
# Meu primeiro erro

print('Olá '+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_451/4017713560.py in <cell line: 0>()
#       1 # Meu primeiro erro
#       2
# ----> 3 print('Olá '+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Como concatenar textos com numeros

print("Olá! Você ficou em: ",5,"ºLugar")
# Out:
# Olá! Você ficou em:  5 ºLugar

# %% [markdown]
# #Variáveis

# %%
nome = "Samuel Santos"
print(nome)
# Out:
# Samuel Santos

# %%
nome = "Samuel Santos"
idade = 18
print("Seu nome é: ", nome, "\n e sua idade é de: ", idade, "anos.")
# Out:
# Seu nome é:  Samuel Santos
#  e sua idade é de:  18 anos.

# %% [markdown]
# ## Algumas regras
# * variaveis não podem começar com números
# * Tambem não podemos utilizar simbolos especiais "$,@,%,#...", mas podemos utilizar '_'(underline)
# * Não podemos usar as seguintes palavras, pois são reservadas
#
# False - class - finally - is - return - None - contiue - for - lambda - try - True - def - from - nonlocal - while - and - del - global - not - with - as - elif - if - or - yield - assert - else - import - pass - break - except - in - raise.

# %% [markdown]
# ## Tipos de Dados

# %%
# str - texto
# a principal caracteristica string (str) é a utilização de aspas '' ""
#
# int - numero inteiro
# float - numero decimal
# a principal caracteristica é um número sem aspas e usando ponto (.) como separador das casas decimais
#
# bool - valor booleando ( Verdadeiro - Falso ) ( False - True )
#
#
print ('texto')
# Out:
# texto

# %%
# verificação do tipo de dado

nome = 'Samuel'
idade = 18
valor = False
pi = 3.14159

print(type(nome))
print(type(idade))
print(type(valor))
print(type)
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'type'>

# %% [markdown]
# ## Entradas do Usuário

# %%
# input
# permite ao usuário digitar um valorm mas não salva a informação, exceto com o uso de uma variavel.

input("Digite o seu nome: ")
# Out:
# Digite o seu nome: oi
# 'oi'

# %%
HelloWord = "print"
print(HelloWord)
# Out:
# print

# %%
print("Olá Samuel" + "\nPrazer em conhecer você!")
# Out:
# Olá Samuel
# Prazer em conhecer você!

# %%
Dia = 16
Mês = 8
Ano = 2007

print("Você nasceu no dia", Dia, "no mes", Mês, "do Ano de", Ano)
# Out:
# Você nasceu no dia 16 no mes 8 do Ano de 2007

# %%
print(3+2)
# Out:
# 5

# %%
dia = input ("Digite o dia do nascimeto: ")
mes = input ("Digite o mes do nascimento: ")
ano = input ("Digite o ano do nascimento: ")

print("Você nasceu no dia", dia, "no mes", mes, "do ano de", ano, ".")
print("Você nasceu no dia "+dia+" de "+mes+" de "+ano+".")

print(f"Você nasceu em {dia} de {mes} de {ano}.")
# Out:
# Digite o dia do nascimeto: oi
# Digite o mes do nascimento: oi
# Digite o ano do nascimento: oi
# Você nasceu no dia oi no mes oi do ano de oi .
# Você nasceu no dia oi de oi de oi.
# Você nasceu em oi de oi de oi.

# %% [markdown]
# ##Operadores Aritmeticas

# %% [markdown]
# exercicio 1:
# converter celsius para fahrenheit

# %%
print("Converta celsius para Fahrenheit")
celsius = float(input("Digite a temperatura em Celsius C°: "))
print(f"{celsius} °C para Fahrenheit é: {celsius*9/5 +32}")
# Out:
# Converta celsius para Fahrenheit
# Digite a temperatura em Celsius C°: 25
# 25.0 °C para Fahrenheit é: 77.0

# %% [markdown]
# exercicio 2 produto sendo descontado

# %%
Produto = float(input("Digite o valor do produto: "))
Desconto = float(input("Digite o valor do desconto: "))
print(f"O valor do produto com desconto é: {Produto - Desconto}")

Todo = ({Produto/Desconto}*100)
print(f"O valor do desconto é: {Todo}%")
# Out:
# Digite o valor do produto: 110
# Digite o valor do desconto: 15
# O valor do produto com desconto é: 95.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_180/547175399.py in <cell line: 0>()
#       3 print(f"O valor do produto com desconto é: {Produto - Desconto}")
#       4
# ----> 5 Todo = ({Produto/Desconto}*100)
#       6 print(f"O valor do desconto é: {Todo}%")
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
#exercicio do professor de produto sendo descontado

#Desconto: informe o valor de um produto e o percentual de desconto.
#Calcule o valor do desconto e o preço final. Exiba os resultados.

produto = float(input("Digite o valor do produto: "))
desconto = float(input("Digite o valor do desconto: "))
VD = produto*(desconto/100)
print(f"O valor do produto com desconto é: {produto - VD}")
# Out:
# Digite o valor do produto: 2000
# Digite o valor do desconto: 15
# O valor do produto com desconto é: 1700.0

# %%
#Exercicio 3
#Velocidade Média: Informe a distância percorrida e o tempo gasto.
#Calcule a velocidade média usando a fórmula: Vm = Distância / Tempo

distancia = float(input("Digite a distancia percorrida: "))
tempo = float(input("Digite o tempo gasto: "))
vm = distancia / tempo

print(f"A velocidade média é: {vm:.1f} km/h")
# Out:
# Digite a distancia percorrida: 277
# Digite o tempo gasto: 5
# A velocidade média é: 55.4 km/h

# %%
# Exercício 2:
# Desconto: Informe o valor de um produto e o percentual de desconto.
# Calcule o valor do desconto e o preço final. Exiba os resultados.


valor = float(input('Digite o valor do produto: '))
desconto = float(input('Digite a % de desconto: '))


vrdesconto = valor * (desconto/100) # 10/100 - 50/100 - 1000 * 0.90
vrfinal = valor-vrdesconto


print(f'Valor do produto: R$ {valor:.2f}')
print(f'% de desconto: {desconto}%')
print(f'Valor do desconto: R$ {vrdesconto:.2f}')
print(f'Valor final: R$ {vrfinal:.2f}')

# %%
# Exercício 1:
# Conversor de Temperatura: temperatura em Celsius. Ex: 25ºc
# Converta para Fahrenheit usando a fórmula: (0°C * 9/5) + 32 = 32°F
# Imprima a temperatura em Fahrenheit.


temperatura = float(input('Digite a temperatura em ºC: '))
fanrenheit = temperatura*(9/5)+32


print(f'A temperatura de {temperatura}ºC em Fahrenheit é de {fanrenheit:.1f}ºF.')

# %%
#Exercicio 4
#Volume do Cubo:
#Solicite a aresta do cubo.
#Calcule o volume usando a fórmula: volume = aresta³

aresta = float(input("informe a aresta do cubo: "))
print(f"O volume do cubo é: {aresta**3}")
# Out:
# informe a aresta do cubo: 3
# O volume do cubo é: 27.0

# %%
#Exercicio 5
#Solicite o ano de nascimento.
#Calcule a idade considerando o ano atual
#Exiba a idade.

nascimento = int(input("Digite o ano de nascimento: "))
ano_atual = int(input("Digite o ano atual: "))
idade = ano_atual - nascimento
print(f"Sua idade é: {idade}")
# Out:
# Digite o ano de nascimento: 2007
# Digite o ano atual: 2026
# Sua idade é: 19

# %%
#Exercicio 6
#Tabuada: solicite um numero.
#Imprima a tabuda desse numero até 10

numero = int(input("Digite um numero: "))
print(f"Tabuada do {numero}:")
print(f"{numero} x 0 = {numero*0}")
print(f"{numero} x 1 = {numero*1}")
print(f"{numero} x 2 = {numero*2}")
print(f"{numero} x 3 = {numero*3}")
print(f"{numero} x 4 = {numero*4}")
print(f"{numero} x 5 = {numero*5}")
print(f"{numero} x 6 = {numero*6}")
print(f"{numero} x 7 = {numero*7}")
print(f"{numero} x 8 = {numero*8}")
print(f"{numero} x 9 = {numero*9}")
print(f"{numero} x 10 = {numero*10}")
# Out:
# Digite um numero: 1
# Tabuada do 1:
# 1 x 0 = 0
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10

# %%
# Exercício 6:
# Tabuada: Solicite um número.
# Imprima a tabuada desse número até 10


numero = int(input('Digite um número: '))


print(f'Exibindo a tabuada do {numero} \n')
print(f'{numero} x  0 = {numero*0}')
print(f'{numero} x  1 = {numero*1}')
print(f'{numero} x  2 = {numero*2}')
print(f'{numero} x  3 = {numero*3}')
print(f'{numero} x  4 = {numero*4}')
print(f'{numero} x  5 = {numero*5}')
print(f'{numero} x  6 = {numero*6}')
print(f'{numero} x  7 = {numero*7}')
print(f'{numero} x  8 = {numero*8}')
print(f'{numero} x  9 = {numero*9}')
print(f'{numero} x 10 = {numero*10}')
