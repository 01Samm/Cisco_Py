# %% [markdown]
# *PRIMEIRO* TESTE

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print ("Hello, World"
# Out:
#   File "/tmp/ipython-input-1558300347.py", line 1
#     print ("Hello, World"
#                          ^
# SyntaxError: incomplete input

# %%
print ("Hello World but that time for the second time")
# Out:
# Hello World but that time for the second time

# %% [markdown]
# COMO FAZER COMENTARIO

# %%
# Utilização da função print
# Fazer um print do texto Olá, Python
print ("Olá, Python")

# Imprimir o seu nome
print ("Sam")
# Out:
# Olá, Python
# Sam

# %% [markdown]
# INSTRUCTION MODULE 1.2.7

# %% [markdown]
# SEPARAÇÃO DE TEXTO APENAS USANDO   print ()

# %%
print("A pequenina aranha escalou a tromba d'água.")
print()
print("Caiu a chuva e lavou a aranha.")
# Out:
# A pequenina aranha escalou a tromba d'água.
#
# Caiu a chuva e lavou a aranha.

# %% [markdown]
# /n NOVA LINHA ou NEW LINE

# %%
print("A aranha pequenininha\nsubiu a tromba d'água.")
print()
print("abaixo veio a chuva\ne lavou a aranha.")
# Out:
# A aranha pequenininha
# subiu a tromba d'água.
#
# abaixo veio a chuva
# e lavou a aranha.

# %% [markdown]
# /t TABULAÇÃO

# %%
print("A aranha pequenininha\tsubiu a tromba d'água.")
print()
print("abaixo veio a chuva\te lavou a aranha.")
# Out:
# A aranha pequenininha	subiu a tromba d'água.
#
# abaixo veio a chuva	e lavou a aranha.

# %% [markdown]
# FORÇANDO ERRO print("\") ou forçar que não é escape segunda é para imprimir print("\\")

# %%
print ("\")
# Out:
#   File "/tmp/ipython-input-1910051548.py", line 1
#     print ("\")
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print ("\\")
# Out:
# \

# %% [markdown]
# A CADA 2 BARRAS FUNCIONA 1

# %%
print ("\\\")
# Out:
#   File "/tmp/ipython-input-1943724907.py", line 1
#     print ("\\\")
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print ("\\\\")
# Out:
# \\

# %% [markdown]
# USANDO VARIOS ARGUMENTOS

# %%
print("A aranha pequenininha", "subiu", "a tromba d'água.")
# Out:
# A aranha pequenininha subiu a tromba d'água.

# %% [markdown]
# USANDO END

# %%
print("Meu nome é", "Python", end=" ")
print("Monty Python")
# Out:
# Meu nome é Python Monty Python

# %% [markdown]
# USANDO SEP

# %%
print("Meu", "nome", "é", "Monty", "Python.", sep="-")
# Out:
# Meu-nome-é-Monty-Python.

# %% [markdown]
# Tentativa de codigo, Usando end e sep

# %%
print("Programação", "Essenciais", "em", sep="_")
print(("Python"), end="...")
# Out:
# Programação_Essenciais_em
# Python...

# %% [markdown]
# TENTATIVAS

# %%
print(3 * 3)
# Out:
# 9

# %%
print(3E8)
# Out:
# 300000000.0

# %%
print("I like \"Monty Python\"")
# Out:
# I like "Monty Python"

# %%
print(True > False)
print(True < False)
# Out:
# True
# False

# %%
print(int("2"))
# Out:
# 2

# %%
print(2 ** 3)
print(2 ** 3.)
print(2. ** 3)
print(2. ** 3.)
# Out:
# 8
# 8.0
# 8.0
# 8.0

# %%
print(2 * 3)
print(2 * 3.)
print(2. * 3)
print(2. * 3.)
# Out:
# 6
# 6.0
# 6.0
# 6.0

# %%
print(6 / 3)
print(6 / 3.)
print(6. / 3)
print(6. / 3.)
# Out:
# 2.0
# 2.0
# 2.0
# 2.0

# %%
var = 1
print(var)
# Out:
# 1

# %%
var = 1
account_balance = 3123
client_name = 'John Doe'
print(var, account_balance, client_name)
print(var)
# Out:
# 1 3123 John Doe
# 1

# %%
a = 3.0
b = 4.0
c = (a ** 2 + b ** 2) ** 0.5
print("c =", c)
# Out:
# c = 5.0

# %% [markdown]
# FIRST TRY CREATING A CODE

# %%
John=3
client_name="John"
print(John,client_name,end=" ")
Mary=5
client_name="Mary"
print(Mary,client_name,end=" ")
Adam=6
client_name="Adam"
print(Adam,client_name,end=" ")
total_apples=(John+Mary+Adam)
print(total_apples)
# Out:
# 3 John 5 Mary 6 Adam 14

# %% [markdown]
# QUEST

# %%
kilometers = 12.25
miles = 7.38

miles_to_kilometers = miles * 1.61
kilometers_to_miles = kilometers / 1.61

print(miles, "milhas é", round(miles_to_kilometers, 2), "quilômetros")
print(kilometers, "quilômetros é", round(kilometers_to_miles, 2), "milhas")
# Out:
# 7.38 milhas é 11.88 quilômetros
# 12.25 quilômetros é 7.61 milhas

# %% [markdown]
# FUNÇÃO INPUT

# %%
print("Conta-me qualquer coisa...")
anything = input()
print("Hum...", anything, "... Realmente?")
# Out:
# Conta-me qualquer coisa...
# hum
# Hum... hum ... Realmente?

# %%
anything = input("Conta-me qualquer coisa...")
print("Hum...", anything, "...Realmente?")
# Out:
# Conta-me qualquer coisa...TT
# Hum... TT ...Realmente?

# %% [markdown]
# INPUT TRY

# %%
anything = float(input("Digite um número: "))
something = anything ** 2.0
print(anything, "elevado a 2 é", something)
# Out:
# Digite um número: ...
# inf elevado a 2 é inf

# %% [markdown]
# other thing

# %%
#calculadora com final
a = float(input("digite um numero "))
b = float(input("digite outro numero "))
print("Adição: ",a+b)
print("Subtração: ",a-b)
print("Multiplicação: ",a*b)
print("Divisão: ",a/b)
print("\nIsso é tudo, pessoal")
# Out:
# digite um numero 70
# digite outro numero 30
# Adição:  100.0
# Subtração:  40.0
# Multiplicação:  2100.0
# Divisão:  2.3333333333333335
#
# Isso é tudo, pessoal

# %%
# calculadora
a = (float(input("digite o valor: ")))
b = (float(input("digite seu segundo valor: ")))

print("adição", a+b)
print("subtração", a-b)
print("multiplicação", a*b)
print("divisão", a/b)
# Out:
# digite o valor: 10
# digite seu segundo valor: 10
# adição 20.0
# subtração 0.0
# multiplicação 100.0
# divisão 1.0

# %%
#se numero aleatorio foi maior que 100 falso se não verdadeiro
n1=float(input("digite um numero: "))
print(n1 <= 100)
# Out:
# digite um numero: 100.5
# False

# %%
#teste1

n1=(input("digite um nome: "))
print(n1 <= sla)
# Out:
# digite um nome: n1
# True

# %%
#teste2

senha = "sla"
print(input("qual a senha?: "))
(senha true if not false)
# Out:
#   File "/tmp/ipython-input-3198275306.py", line 3
#     (if is senha true if not false)
#      ^
# SyntaxError: invalid syntax

# %%
#
num2 = int(input("digite um numero quebrado: "))
if num2 >= 100:
  print("é maior.")
else:
  print("é menor")
# Out:
# digite um numero quebrado: 30
# é menor

# %%
#ler dois numeros
number1 = int(input("Digite o primeiro número: "))
number2 = int(input("Digite o segundo número: "))

#Escolher o numero maior
if number1 > number2:
   larger_number = number1
else:
   larger_number = number2

#imprimir o resultado
print("O maior número é:", larger_number)
# Out:
# Digite o primeiro número: 12
# Digite o segundo número: 12
# O maior número é: 12

# %%
# Leia três números.
number7 = int(input("Digite o primeiro número: "))
number5 = int(input("Digite o segundo número: "))
number8 = int(input("Digite o terceiro número: "))

# Verifique qual dos números é o maior
# e passe-o para a variável de número_maior.

largest_number = max(number7, number5, number8)

# Imprimir o resultado.
print("O maior número é:", largest_number)
# Out:
# Digite o primeiro número: 123
# Digite o segundo número: 321
# Digite o terceiro número: 231
# O maior número é: 321

# %%
entrada=(input("qual é a melhor fabrica do mundo?"))
if entrada == "Bauducco":
  print("Sim, Bauducco é a maior fabrica de todos os tempos!")
elif entrada == "bauducco":
  print("ta errado emm")
else:
  print("refazz moçooo")
# Out:
# qual é a melhor fabrica do mundo?iio
# refazz moçooo iio

# %%
nome_escola = input("informa o nome da escola:")
qtde_caracters = len(nome_escola)
print(qtde_caracters)
# Out:
# informa o nome da escola:oi
# 2

# %%
resposta_do_ususario=input("digite um numero: ")
quantidade_caracteres = len(resposta_do_ususario)
if quantidade_caracteres == 11:
  print("E um CPF")
elif quantidade_caracteres == 14:
  print("E um CNPJ")
else:
  print("Tente Novamente, coloque um CPF ou um CNPJ")
# Out:
# digite um numero: 12312312312313
# E um CNPJ

# %%
#codigo infinito cuidado!
while True:
    print("Estou preso dentro de um loop.")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# Estou preso dentro de um loop.
# ...

# %%
# Um programa que lê uma sequência de números
# e conta quantos números são pares e quantos são ímpares.
# O programa termina quando zero é digitado.

odd_numbers = 0
even_numbers = 0

# Leia o primeiro número.
number = int(input("Digite um número ou digite 0 para parar: "))

# 0 termina a execução.
while number != 0:
    # Verifique se o número é ímpar.
    if number % 2 == 1:
        # Aumente o contador odd_numbers.
        odd_numbers += 1
    else:
        # Aumente o contador even_numbers.
        even_numbers += 1
    # Leia o número seguinte.
    number = int(input("Digite um número ou digite 0 para parar: "))

# Imprimir resultados.
print("Números ímpares contam:", odd_numbers)
print("Números pares contam:", even_numbers)
# Out:
# Digite um número ou digite 0 para parar: 8
# Digite um número ou digite 0 para parar: 9
# Digite um número ou digite 0 para parar: 10
# Digite um número ou digite 0 para parar: 11
# Digite um número ou digite 0 para parar: 12
# Digite um número ou digite 0 para parar: 13
# Digite um número ou digite 0 para parar: 0
# Números ímpares contam: 3
# Números pares contam: 3

# %%
secret_number = 777

print(
"""
+===================================+
| Bem vindo ao meu jogo, trouxa!    |
| Insira um número inteiro          |
| e adivinhar o número que tenho    |
| escolhidos para você.             |
| Então, qual é o número secreto?   |
+===================================+
""")
# Out:
# +===================================+
# | Bem vindo ao meu jogo, trouxa!    |
# | Insira um número inteiro          |
# | e adivinhar o número que tenho    |
# | escolhidos para você.             |
# | Então, qual é o número secreto?   |
# +===================================+
#
# digite o codigo secreto777
# try again

# %%
for i in range (2, 8):
  print("O valor de i é atualmente", i)
# Out:
# O valor de i é atualmente 2
# O valor de i é atualmente 3
# O valor de i é atualmente 4
# O valor de i é atualmente 5
# O valor de i é atualmente 6
# O valor de i é atualmente 7

# %%
for i in range (1, 8, 2):
  print("O valor de i é atualmente", i)
# Out:
# O valor de i é atualmente 1
# O valor de i é atualmente 3
# O valor de i é atualmente 5
# O valor de i é atualmente 7

# %%
for i in range (0, 100, 2)
  print("o valor de i é atualmente", i)
# Out:
#   File "/tmp/ipython-input-622963605.py", line 1
#     for i in range (0, 100, 2)
#                               ^
# SyntaxError: expected ':'

# %%
for i range(0, 101, 3):
  print("O valor da i é atualmente", i)

# %%
for i in range(1, 6):
  print("missiissipi", i)
# Out:
# missiissipi 1
# missiissipi 2
# missiissipi 3
# missiissipi 4
# missiissipi 5

# %%
import time

print("Inicio...")
time.sleep(7)
print("Fim")
# Out:
# Inicio...
# Fim

# %%
import time
print("Inicio 0...")
for i in range(1, 6):
  time.sleep(3)
  print("mississipi", i)
print("Fim")
# Out:
# Inicio 0...
# mississipi 1
# mississipi 2
# mississipi 3
# mississipi 4
# mississipi 5
# Fim

# %% [markdown]
# laço

# %%
# break - exemplo

print("The break instrução:")
for i in range(1, 6):
    if i == 3:
        break
    print("Dentro do laço.", i)
print("Fora do loop.")


# continue - exemplo

print("The continue instrução:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Dentro do laço.", i)
print("Fora do loop.")
# Out:
# The break instrução:
# Dentro do laço. 1
# Dentro do laço. 2
# Fora do loop.
# The continue instrução:
# Dentro do laço. 1
# Dentro do laço. 2
# Dentro do laço. 4
# Dentro do laço. 5
# Fora do loop.

# %%
senha = "chupacabra"
usuario=input("digite a senha: ")
while usuario != senha:
  print("senha incorreta")
  usuario=input("digite a senha: ")
print("a senha enta correta, vamos ao avanço!")
# Out:
# digite a senha: oi
# senha incorreta
# digite a senha: oi
# senha incorreta
# digite a senha: chupacabra
# a senha enta correta, vamos ao avanço!

# %%
while True:
  resposta=input("digite a senha: ")
  if resposta == "chupacabra":
    break
print("logado com sucesso")

# %% [markdown]
# UPPER TRANSFORMA EM LETRA MAIUSCULA

# %%
nome = input("digite seu nome: ").upper()
print(nome)
# Out:
# digite seu nome: oi
# OI

# %%
for letra in nome:
  print(letra)

# %%
resp = input("digite uma palavra: ").upper()

for r in resp:
    if r == 'A':
      continue
    elif r == 'E':
      continue
    elif r == 'I':
      continue
    elif r == 'O':
      continue
    elif r == 'U':
      continue
    print(r)
# Out:
# digite uma palavra: ei

# %% [markdown]
# Armazenar vogais

# %%
i = 1
while i < 5:
    print(i)
    i += 1
else:
    print("else:", i)
# Out:
# 1
# 2
# 3
# 4
# else: 5

# %% [markdown]
# exercicio resposta

# %%
for ch in "john.smith@pythoninstitute.org":
    if ch == "@":
        break
    print(ch, end="")

# %% [markdown]
# LISTA

# %%
numbers = [10, 5, 7, 2, 1]

# %%
numbers = [10, 5, 7, 2, 1]
type(numeros)

list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3670569774.py in <cell line: 0>()
#       1 numbers = [10, 5, 7, 2, 1]
# ----> 2 type(numeros)
#       3
#       4 list
#
# NameError: name 'numeros' is not defined

# %%
numbers = [10, 5, 7, 2, 1]
print("Conteúdos originais da lista:", numbers)  # Imprimindo o conteúdo original da lista.

numbers[0] = 111
print("Novo conteúdo da lista: ", numbers)  # Conteúdo atual da lista.
# Out:
# Conteúdos originais da lista: [10, 5, 7, 2, 1]
# Novo conteúdo da lista:  [111, 5, 7, 2, 1]

# %%
print(numbers[0])
# Out:
# 10

# %% [markdown]
# REMOVENDO CENARIO DE UMA LISTA

# %%
del numbers[1]
print(len(numbers))
print(numbers)
# Out:
# 3
# [10, 2, 1]

# %% [markdown]
# outro codigo

# %%
my_list = [] # Criando uma lista vazia.

for i in range(5):
   my_list.append (i + 1)

print (my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list = []  # Criando uma lista vazia.

for i in range(5):
    my_list.insert(0, i + 1)

print(my_list)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# utilização de lista

# %%
my_list = [10, 1, 8, 3, 5]

total = 0

for i in range(len(my_list)):

  total += my_list[i]

print(total)
# Out:
# 27

# %%
colors = ["red, blue, purple, brown, yellow"]
for i in range(len(colors)):
  print(colors[i])
# Out:
# red, blue, purple, brown, yellow

# %%
colors = ["red, blue, purple, brown, yellow"]
for i in range(len(colors)):
  print(colors[i])
# Out:
# red, blue, purple, brown, yellow

# %%
lst = [1, 2, 3, 4, 5]
lst.insert(1, 6)
del lst[0]
lst.append(1)

print(lst)
# Out:
# [6, 2, 3, 4, 5, 1]

# %%
lst = [1, 2, 3, 4, 5]
lst_2 = []
add = 0

for number in lst:
    add += number
    lst_2.append(add)

print(lst_2)
# Out:
# [1, 3, 6, 10, 15]

# %%
list_1 = [1]
list_2 = list_1
list_1[0] = 2
print(list_2)
# Out:
# [2]

# %%
cidades = [['SP','CE','PI'],['Ubatuba','Guanaces','Teresina']]

print(cidades[0][0])
print(cidades[1][0])
print(cidades[1][1])
print(cidades[1][2])
print(cidades[0][2])
print(cidades[0][1])
# Out:
# SP
# Ubatuba
# Guanaces
# Teresina
# PI
# CE

# %% [markdown]
# regras das variaveis
# não pode começar com numero
# caracteres...

# %%
def message ():
    print("entre um valor: ")

# %%
def message ():
    print("entre um valor: ")

print("começamos aqui.")
message()
print ("terminamos aqui.")
# Out:
# começamos aqui.
# entre um valor:
# terminamos aqui.

# %%
print("Enter a value: ")
a = int(input())

print("Enter a value: ")
b = int(input())

print("Enter a value: ")
c = int(input())

abs
# Out:
# Enter a value:
# 1
# Enter a value:
# 2
# Enter a value:
# 3
# <function abs(x, /)>

# %%
def message(number):
    print("Enter a number:", number)

message(1)
# Out:
# Enter a number: 1

# %%
def message(what, number):
    print("Enter", what, "number", number)

message("telephone", 11)
message("price", 5)
message("number", "number")
# Out:
# Enter telephone number 11
# Enter price number 5
# Enter number number number

# %% [markdown]
# escopos testes

# %%
def scope_test():
    x = 123


scope_test()
print(x)

# %% [markdown]
# dicionario

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}
phone_numbers = {'boss': 5551234567, 'Suzy': 22657854310}
empty_dictionary = {}

print(dictionary)
print(phone_numbers)
print(empty_dictionary)
# Out:
# {'cat': 'chat', 'dog': 'chien', 'horse': 'cheval'}
# {'boss': 5551234567, 'Suzy': 22657854310}
# {}

# %%
print(dictionary['cat'])
print(phone_numbers['Suzy'])
# Out:
# chat
# 22657854310

# %%
dictionary = {"cat": "chat", "dog": "chien", "horse": "cheval"}
words = ['cat', 'lion', 'horse']

for word in words:
    if word in dictionary:
        print(word, "->", dictionary[word])
    else:
        print(word, "is not in dictionary")
 #se palavra em palavra, ou seja pega e faz uma verificação de variaveis, ou seja faz uma filtração, se word ou seja
# Out:
# cat -> chat
# lion is not in dictionary
# horse -> cheval

# %% [markdown]
# prova teste

# %%
import requests

url = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": -23.65203528204488,
    "longitude": -46.71268347442429,
    "current_weather": True
}

res = requests.get(url, params=params)
dados = res.json()

print(dados)
print(dados['current_weather'])
# Out:
# {'latitude': -23.625, 'longitude': -46.75, 'generationtime_ms': 27.696609497070312, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 742.0, 'current_weather_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature': '°C', 'windspeed': 'km/h', 'winddirection': '°', 'is_day': '', 'weathercode': 'wmo code'}, 'current_weather': {'time': '2026-02-21T17:30', 'interval': 900, 'temperature': 25.3, 'windspeed': 13.9, 'winddirection': 159, 'is_day': 1, 'weathercode': 3}}
# {'time': '2026-02-21T17:30', 'interval': 900, 'temperature': 25.3, 'windspeed': 13.9, 'winddirection': 159, 'is_day': 1, 'weathercode': 3}

# %%
from IPython.core.compilerop import CachingCompiler
import requests

url = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": -23.65203528204488,
    "longitude": -46.71268347442429,
    "current_weather": True
}

res = requests.get(url, params=params)
dados = res.json()

#print (dados)
print("temperatura atual em Senai Ary Torres: ", dados['current_weather']['temperature'], "°C")
print("Vento: ", dados ['current_weather']['windspeed'], "km/h")
# Out:
# temperatura atual em Senai Ary Torres:  24.8 °C
# Vento:  14.5 km/h

# %%
temperature = float(input('Enter current temperature:'))

if temperature > 0:
    print("Above zero")
elif temperature < 0:
    print("Below zero")
else:
    print("Zero")
# Out:
# Enter current temperature:-10
# Below zero
